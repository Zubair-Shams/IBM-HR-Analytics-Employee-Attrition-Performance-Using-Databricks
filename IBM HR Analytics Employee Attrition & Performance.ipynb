# %%
from pyspark.sql import SparkSession

# %%
from pyspark.sql.types import *

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
plt.rcParams['figure.dpi'] = 100

# %%
appName = "IBM HR Analytics Employee Attrition & Performance"
spark = SparkSession \
    .builder \
    .appName(appName) \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
# File location and type
file_location = "/FileStore/tables/HR_Employee_Attrition.csv"    #load the file and store in specific location
file_type = "csv"                                                #the file type is cvs
# CSV options
infer_schema = "false"
first_row_is_header = "false"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
dataframe = spark.read.format(file_type) \ 
  .option("inferSchema", infer_schema) \
  .option("header", True) \
  .option("sep", delimiter) \
  .load(file_location)

display(dataframe)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dataframe.show(,False)
# Out:
# +---+---------+--------------+---------+----------+----------------+---------+--------------+-------------+--------------+-----------------------+------+----------+--------------+--------+---------------+---------------+-------------+-------------+-----------+------------------+------+--------+-----------------+-----------------+------------------------+-------------+----------------+-----------------+---------------------+---------------+--------------+------------------+-----------------------+--------------------+
# ...

# %%
dataframe.printSchema()
# Out:
# root
#  |-- Age: string (nullable = true)
#  |-- Attrition: string (nullable = true)
#  |-- BusinessTravel: string (nullable = true)
#  |-- DailyRate: string (nullable = true)
#  |-- Department: string (nullable = true)
#  |-- DistanceFromHome: string (nullable = true)
#  |-- Education: string (nullable = true)
#  |-- EducationField: string (nullable = true)
#  |-- EmployeeCount: string (nullable = true)
#  |-- EmployeeNumber: string (nullable = true)
#  |-- EnvironmentSatisfaction: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- HourlyRate: string (nullable = true)
#  |-- JobInvolvement: string (nullable = true)
#  |-- JobLevel: string (nullable = true)
#  |-- JobRole: string (nullable = true)
#  |-- JobSatisfaction: string (nullable = true)
#  |-- MaritalStatus: string (nullable = true)
#  |-- MonthlyIncome: string (nullable = true)
#  |-- MonthlyRate: string (nullable = true)
#  |-- NumCompaniesWorked: string (nullable = true)
# ...

# %%
dataframe.columns
# Out:
# Out[43]: ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
dataframe.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in dataframe.columns]).show(vertical = True)
# Out:
# -RECORD 0-----------------------
#  Age                      | 0
#  Attrition                | 0
#  BusinessTravel           | 0
#  DailyRate                | 0
#  Department               | 0
#  DistanceFromHome         | 0
#  Education                | 0
#  EducationField           | 0
#  EmployeeCount            | 0
#  EmployeeNumber           | 0
#  EnvironmentSatisfaction  | 0
#  Gender                   | 0
#  HourlyRate               | 0
#  JobInvolvement           | 0
#  JobLevel                 | 0
#  JobRole                  | 0
#  JobSatisfaction          | 0
#  MaritalStatus            | 0
#  MonthlyIncome            | 0
#  MonthlyRate              | 0
#  NumCompaniesWorked       | 0
#  Over18                   | 0
#  OverTime                 | 0
#  PercentSalaryHike        | 0
#  PerformanceRating        | 0
#  RelationshipSatisfaction | 0
#  StandardHours            | 0
#  StockOptionLevel         | 0
#  TotalWorkingYears        | 0
#  TrainingTimesLastYear    | 0
# ...

# %%
dataframe.describe().show(vertical = True)
# Out:
# -RECORD 0----------------------------------------
#  summary                  | count
#  Age                      | 1470
#  Attrition                | 1470
#  BusinessTravel           | 1470
#  DailyRate                | 1470
#  Department               | 1470
#  DistanceFromHome         | 1470
#  Education                | 1470
#  EducationField           | 1470
#  EmployeeCount            | 1470
#  EmployeeNumber           | 1470
#  EnvironmentSatisfaction  | 1470
#  Gender                   | 1470
#  HourlyRate               | 1470
#  JobInvolvement           | 1470
#  JobLevel                 | 1470
#  JobRole                  | 1470
#  JobSatisfaction          | 1470
#  MaritalStatus            | 1470
#  MonthlyIncome            | 1470
#  MonthlyRate              | 1470
#  NumCompaniesWorked       | 1470
#  Over18                   | 1470
#  OverTime                 | 1470
#  PercentSalaryHike        | 1470
#  PerformanceRating        | 1470
#  RelationshipSatisfaction | 1470
# ...

# %%
dataframe.select('MonthlyIncome').describe().show()
# Out:
# +-------+-----------------+
# |summary|    MonthlyIncome|
# +-------+-----------------+
# |  count|             1470|
# |   mean|6502.931292517007|
# | stddev|4707.956783097992|
# |    min|            10008|
# |    max|             9998|
# +-------+-----------------+

# %%
#As we can see in feature Monthly income we have some outliers, we will deal outliers by using Median Absolute deviation (MAD)
import pyspark.sql.functions as F

# %%
MAD_dataframe = dataframe.groupby('Attrition').agg(F.expr('percentile(MonthlyIncome, array(0.5))')[0].alias('MonthlyIncome_median'))\
            .join(dataframe, "Attrition", "left").withColumn("MonthlyIncome_difference_median",
                F.abs(F.col('MonthlyIncome')-F.col('MonthlyIncome_median')))\
                .groupby('Attrition', 'MonthlyIncome_median')\
                .agg(F.expr('percentile(MonthlyIncome_difference_median, array(0.5))')[0].alias('median_absolute_difference'))




RemovedOutliers = dataframe.join(MAD_dataframe, "Attrition", "left")\
                .filter(F.abs(F.col("MonthlyIncome")-F.col("MonthlyIncome_median"))
                        <= (F.col("median_absolute_difference")*3))

# %%
#See that max monthly incomes are reduced
RemovedOutliers.select('MonthlyIncome').describe().show()
# Out:
# +-------+------------------+
# |summary|     MonthlyIncome|
# +-------+------------------+
# |  count|              1237|
# |   mean| 4839.505254648343|
# | stddev|2519.3679565835682|
# |    min|              1009|
# |    max|              9998|
# +-------+------------------+

# %%
RemovedOutliers.where('YearsAtCompany == 0').show(1,vertical = True)
# Out:
# -RECORD 0-------------------------------------
#  Attrition                  | No
#  Age                        | 42
#  BusinessTravel             | Travel_Rarely
#  DailyRate                  | 419
#  Department                 | Sales
#  DistanceFromHome           | 12
#  Education                  | 4
#  EducationField             | Marketing
#  EmployeeCount              | 1
#  EmployeeNumber             | 1943
#  EnvironmentSatisfaction    | 2
#  Gender                     | Male
#  HourlyRate                 | 77
#  JobInvolvement             | 3
#  JobLevel                   | 2
#  JobRole                    | Sales Executive
#  JobSatisfaction            | 4
#  MaritalStatus              | Divorced
#  MonthlyIncome              | 5087
#  MonthlyRate                | 2900
#  NumCompaniesWorked         | 3
#  Over18                     | Y
#  OverTime                   | Yes
#  PercentSalaryHike          | 12
#  PerformanceRating          | 3
#  RelationshipSatisfaction   | 3
# ...

# %%
RemovedOutliers.groupBy('Department','YearsAtCompany').agg(count('YearsAtCompany'),sum('MonthlyIncome'))\
.sort('count(YearsAtCompany)')\
.show(10)
# Out:
# +--------------------+--------------+---------------------+------------------+
# |          Department|YearsAtCompany|count(YearsAtCompany)|sum(MonthlyIncome)|
# +--------------------+--------------+---------------------+------------------+
# |Research & Develo...|            24|                    1|            5210.0|
# |               Sales|            24|                    1|           10453.0|
# |               Sales|            16|                    1|           10609.0|
# |Research & Develo...|            26|                    1|            7403.0|
# |Research & Develo...|            23|                    1|           10748.0|
# |               Sales|            22|                    1|           10447.0|
# |Research & Develo...|            21|                    1|           10880.0|
# |Research & Develo...|            30|                    1|           11245.0|
# |               Sales|            20|                    2|           16938.0|
# ...

# %%
#converting spark dataset to pandas
pd_dataframe= RemovedOutliers.toPandas()
pd_dataframe.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Attrition</th>
#       <th>Age</th>
#       <th>BusinessTravel</th>
#       <th>DailyRate</th>
#       <th>Department</th>
#       <th>DistanceFromHome</th>
#       <th>Education</th>
#       <th>EducationField</th>
#       <th>EmployeeCount</th>
#       <th>EmployeeNumber</th>
#       <th>...</th>
#       <th>StockOptionLevel</th>
#       <th>TotalWorkingYears</th>
#       <th>TrainingTimesLastYear</th>
#       <th>WorkLifeBalance</th>
#       <th>YearsAtCompany</th>
#       <th>YearsInCurrentRole</th>
#       <th>YearsSinceLastPromotion</th>
#       <th>YearsWithCurrManager</th>
# ...

# %%
plt.figure(figsize=(14,5))
sns.countplot(x= pd_dataframe.Age.sort_values())
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.countplot(pd_dataframe.EducationField.sort_values())
# Out:
# /databricks/python/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Out[148]: <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %%
Age_Att = pd_dataframe.groupby(['YearsAtCompany','Attrition']).apply(lambda x:x['Attrition'].count()).reset_index(name='AttritionRate')

plt.figure(figsize=(10,3))
sns.lineplot(data=Age_Att, x='YearsAtCompany',y='AttritionRate',hue='Attrition')
plt.title("Attrition based on The employees' work")
plt.ylabel('Attrition Rate')
plt.xlabel('Years worked at that Company')
plt .show()

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(data=pd_dataframe,x='Education',hue='Attrition',palette='summer')
ax.set_xticklabels([ '1-Below College' , '2-College' , '3-Bachelor' ,'4-Master',  '5-Doctor'])
plt.show()

# %%
plt.figure(figsize=(8,5))
ax = sns.countplot(data=pd_dataframe,x='Department',hue='Attrition')
plt.show()

# %%
plt.figure(figsize=(13,5))
ax = sns.countplot(data=pd_dataframe,x='Age',hue='Attrition')
plt.show()
